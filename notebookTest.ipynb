# %%
import FuncionesSimulador as func
import matplotlib as plt
import matplotlib.pyplot as plt
import math           # Funciones matematicas (de C)

Ts= 1*1e-6 
Tau = 1*1e-3
NumStages = 10
Pulse, t_pulse = func.func_CreatePulse(Ts,Tau,NumStages)

plt.plot(t_pulse,Pulse)
print(t_pulse)
# Out:
# [0.0000e+00 1.0000e-06 2.0000e-06 ... 4.9999e-02 5.0000e-02 5.0001e-02]

# %%
import yaml

# Crear un diccionario en Python
mi_diccionario = {
    'nombre': 'Juan Pérez',
    'edad': 30,
    'ciudad': 'Ejemploville',
    'intereses': ['programación', 'música', 'deportes']
}

# Ruta del archivo YAML
ruta_archivo_yaml = 'mi_archivo.yaml'

# Guardar el diccionario en un archivo YAML
with open(ruta_archivo_yaml, 'w') as archivo_yaml:
    yaml.dump(mi_diccionario, archivo_yaml, default_flow_style=False)

print(f'Se ha creado el archivo YAML en: {ruta_archivo_yaml}')
# Out:
# Se ha creado el archivo YAML en: mi_archivo.yaml

# %%
# Guardar StructConfiguration en un archivo (suponiendo que FileNameStructConfiguration está definido)
with open(FileNameStructConfiguration, 'w+') as file:
    file.write(str(StructConfiguration))

# %%
import numpy as np    # Manejo con arrays
Ts= 1*1e-6 
Tmed = 1
Rin = 100
RandomNotPeriodic = 0

VecEventTime, t_abs = func.func_CreateEventTime(Rin, Tmed, Ts, RandomNotPeriodic)
plt.plot(t_abs,VecEventTime)

print(np.size(VecEventTime))
print(np.size(t_abs))
# Out:
# 1000001
# 1000001

# %%
RANDOM_AMP = 1 
AmpRandomness = RANDOM_AMP 
Amp_FotoPico = 5  # valor de tension correspondiente a la amplitud del pulso mas probable
DetectorResolution = 3  # resolucion del detector en porciento FWHM/Ecentral = 

NumEvents =  sum(VecEventTime)

print(len(f_x))
print(len(x))
print(NumEvents)
f_x , x= func.func_CreateAmpDistribution(AmpRandomness, DetectorResolution, Amp_FotoPico)
VecEventAmp  = func.func_CreateEventAmp( NumEvents , f_x , x )
VecEventTimeAmp = func.func_ModulateEvent(VecEventTime, VecEventAmp)
plt.plot(VecEventTimeAmp)
# Out:
# 9901
# 9901
# 100.0

# %%
np.random.rand(100)
# Out:
# array([0.26595662, 0.97459468, 0.66059511, 0.72860327, 0.85298601,
#        0.37316082, 0.77447884, 0.70364841, 0.5865171 , 0.38832845,
#        0.32068541, 0.90564031, 0.46787686, 0.36041253, 0.75778228,
#        0.23926431, 0.72916312, 0.69666979, 0.60962841, 0.57148845,
#        0.95339193, 0.29334181, 0.12101378, 0.71966158, 0.26010214,
#        0.97636753, 0.0010469 , 0.75544228, 0.09161623, 0.82761635,
#        0.41033962, 0.67514774, 0.41699639, 0.5654302 , 0.28685246,
#        0.71022456, 0.17936428, 0.41692428, 0.70917098, 0.5253726 ,
#        0.09113714, 0.02985382, 0.37174896, 0.90326925, 0.81809967,
#        0.64595177, 0.21633836, 0.8653308 , 0.25845551, 0.22143639,
#        0.79672945, 0.8389359 , 0.86559698, 0.40936391, 0.54666344,
#        0.6159395 , 0.77326144, 0.29822472, 0.76916512, 0.63556854,
#        0.5858335 , 0.22580731, 0.14538107, 0.49682226, 0.18037104,
#        0.56835005, 0.49640287, 0.00442956, 0.2198944 , 0.87433796,
# ...
